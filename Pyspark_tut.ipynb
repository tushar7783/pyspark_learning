# %% [markdown]
# create spark session

# %%
# spark session
from pyspark.sql import SparkSession
spark=(
    SparkSession
    .builder
    .appName('my spark')
    .getOrCreate()
    
)

# %%
spark

# %%
# data 
emp_data = [
    ["001","101","John Doe","30","Male","50000","2015-01-01"],
    ["002","101","Jane Smith","25","Female","45000","2016-02-15"],
    ["003","102","Bob Brown","35","Male","55000","2014-05-01"],
    ["004","102","Alice Lee","28","Female","48000","2017-09-30"],
    ["005","103","Jack Chan","40","Male","60000","2013-04-01"],
    ["006","103","Jill Wong","32","Female","52000","2018-07-01"],
    ["007","101","James Johnson","42","Male","70000","2012-03-15"],
    ["008","102","Kate Kim","29","Female","51000","2019-10-01"],
    ["009","103","Tom Tan","33","Male","58000","2016-06-01"],
    ["010","104","Lisa Lee","27","Female","47000","2018-08-01"],
    ["011","104","David Park","38","Male","65000","2015-11-01"],
    ["012","105","Susan Chen","31","Female","54000","2017-02-15"],
    ["013","106","Brian Kim","45","Male","75000","2011-07-01"],
    ["014","107","Emily Lee","26","Female","46000","2019-01-01"],
    ["015","106","Michael Lee","37","Male","63000","2014-09-30"],
    ["016","107","Kelly Zhang","30","Female","49000","2018-04-01"],
    ["017","105","George Wang","34","Male","57000","2016-03-15"],
    ["018","104","Nancy Liu","29","Female","50000","2017-06-01"],
    ["019","103","Steven Chen","36","Male","62000","2015-08-01"],
    ["020","102","Grace Kim","32","Female","53000","2018-11-01"]
]

# schema 
emp_schema = "employee_id string, department_id string, name string, age string, gender string, salary string, hire_date string"

# %%
# cretae data frame 
emp=spark.createDataFrame(data=emp_data,schema=emp_schema)
# display data frame 
display(emp)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employee_id</th><th>department_id</th><th>name</th><th>age</th><th>gender</th><th>salary</th><th>hire_date</th></tr></thead><tbody><tr><td>001</td><td>101</td><td>John Doe</td><td>30</td><td>Male</td><td>50000</td><td>2015-01-01</td></tr><tr><td>002</td><td>101</td><td>Jane Smith</td><td>25</td><td>Female</td><td>45000</td><td>2016-02-15</td></tr><tr><td>003</td><td>102</td><td>Bob Brown</td><td>35</td><td>Male</td><td>55000</td><td>2014-05-01</td></tr><tr><td>004</td><td>102</td><td>Alice Lee</td><td>28</td><td>Female</td><td>48000</td><td>2017-09-30</td></tr><tr><td>005</td><td>103</td><td>Jack Chan</td><td>40</td><td>Male</td><td>60000</td><td>2013-04-01</td></tr><tr><td>006</td><td>103</td><td>Jill Wong</td><td>32</td><td>Female</td><td>52000</td><td>2018-07-01</td></tr><tr><td>007</td><td>101</td><td>James Johnson</td><td>42</td><td>Male</td><td>70000</td><td>2012-03-15</td></tr><tr><td>008</td><td>102</td><td>Kate Kim</td><td>29</td><td>Female</td><td>51000</td><td>2019-10-01</td></tr><tr><td>009</td><td>103</td><td>Tom Tan</td><td>33</td><td>Male</td><td>58000</td><td>2016-06-01</td></tr><tr><td>010</td><td>104</td><td>Lisa Lee</td><td>27</td><td>Female</td><td>47000</td><td>2018-08-01</td></tr><tr><td>011</td><td>104</td><td>David Park</td><td>38</td><td>Male</td><td>65000</td><td>2015-11-01</td></tr><tr><td>012</td><td>105</td><td>Susan Chen</td><td>31</td><td>Female</td><td>54000</td><td>2017-02-15</td></tr><tr><td>013</td><td>106</td><td>Brian Kim</td><td>45</td><td>Male</td><td>75000</td><td>2011-07-01</td></tr><tr><td>014</td><td>107</td><td>Emily Lee</td><td>26</td><td>Female</td><td>46000</td><td>2019-01-01</td></tr><tr><td>015</td><td>106</td><td>Michael Lee</td><td>37</td><td>Male</td><td>63000</td><td>2014-09-30</td></tr><tr><td>016</td><td>107</td><td>Kelly Zhang</td><td>30</td><td>Female</td><td>49000</td><td>2018-04-01</td></tr><tr><td>017</td><td>105</td><td>George Wang</td><td>34</td><td>Male</td><td>57000</td><td>2016-03-15</td></tr><tr><td>018</td><td>104</td><td>Nancy Liu</td><td>29</td><td>Female</td><td>50000</td><td>2017-06-01</td></tr><tr><td>019</td><td>103</td><td>Steven Chen</td><td>36</td><td>Male</td><td>62000</td><td>2015-08-01</td></tr><tr><td>020</td><td>102</td><td>Grace Kim</td><td>32</td><td>Female</td><td>53000</td><td>2018-11-01</td></tr></tbody></table></div>

# %%
#chevk no of partiotion
emp.rdd.getNumPartitions()
# Out:
# ---------------------------------------------------------------------------
# PySparkNotImplementedError                Traceback (most recent call last)
# File <command-6027662273965412>, line 2
#       1 #chevk no of partiotion
# ----> 2 emp.rdd.getNumPartitions()
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/dataframe.py:2470, in DataFrame.rdd(self)
#    2468 @property
#    2469 def rdd(self) -> "RDD[Row]":
# -> 2470     raise PySparkNotImplementedError(
#    2471         errorClass="RDD_NOT_SUPPORTED",
#    2472         messageParameters={},
#    2473     )
#
# PySparkNotImplementedError: [RDD_NOT_SUPPORTED] Using custom code using PySpark RDDs is not allowed on serverless compute. We suggest using mapInPandas or mapInArrow for the most common use cases, or switch to Dedicated access mode if you require RDDs. For more details on compatibility and limitations, check: https://docs.databricks.com/release-notes/serverless.html#limitations

# %%
#show data(action)
emp.show()
# Out:
# +-----------+-------------+-------------+---+------+------+----------+
# |employee_id|department_id|         name|age|gender|salary| hire_date|
# +-----------+-------------+-------------+---+------+------+----------+
# |        001|          101|     John Doe| 30|  Male| 50000|2015-01-01|
# |        002|          101|   Jane Smith| 25|Female| 45000|2016-02-15|
# |        003|          102|    Bob Brown| 35|  Male| 55000|2014-05-01|
# |        004|          102|    Alice Lee| 28|Female| 48000|2017-09-30|
# |        005|          103|    Jack Chan| 40|  Male| 60000|2013-04-01|
# |        006|          103|    Jill Wong| 32|Female| 52000|2018-07-01|
# |        007|          101|James Johnson| 42|  Male| 70000|2012-03-15|
# |        008|          102|     Kate Kim| 29|Female| 51000|2019-10-01|
# |        009|          103|      Tom Tan| 33|  Male| 58000|2016-06-01|
# |        010|          104|     Lisa Lee| 27|Female| 47000|2018-08-01|
# |        011|          104|   David Park| 38|  Male| 65000|2015-11-01|
# |        012|          105|   Susan Chen| 31|Female| 54000|2017-02-15|
# |        013|          106|    Brian Kim| 45|  Male| 75000|2011-07-01|
# |        014|          107|    Emily Lee| 26|Female| 46000|2019-01-01|
# |        015|          106|  Michael Lee| 37|  Male| 63000|2014-09-30|
# |        016|          107|  Kelly Zhang| 30|Female| 49000|2018-04-01|
# |        017|          105|  George Wang| 34|  Male| 57000|2016-03-15|
# |        018|          104|    Nancy Liu| 29|Female| 50000|2017-06-01|
# |        019|          103|  Steven Chen| 36|  Male| 62000|2015-08-01|
# |        020|          102|    Grace Kim| 32|Female| 53000|2018-11-01|
# +-----------+-------------+-------------+---+------+------+----------+

# %%
emp_final=emp.where("salary>50000")
emp_final.show()
# Out:
# +-----------+-------------+-------------+---+------+------+----------+
# |employee_id|department_id|         name|age|gender|salary| hire_date|
# +-----------+-------------+-------------+---+------+------+----------+
# |        003|          102|    Bob Brown| 35|  Male| 55000|2014-05-01|
# |        005|          103|    Jack Chan| 40|  Male| 60000|2013-04-01|
# |        006|          103|    Jill Wong| 32|Female| 52000|2018-07-01|
# |        007|          101|James Johnson| 42|  Male| 70000|2012-03-15|
# |        008|          102|     Kate Kim| 29|Female| 51000|2019-10-01|
# |        009|          103|      Tom Tan| 33|  Male| 58000|2016-06-01|
# |        011|          104|   David Park| 38|  Male| 65000|2015-11-01|
# |        012|          105|   Susan Chen| 31|Female| 54000|2017-02-15|
# |        013|          106|    Brian Kim| 45|  Male| 75000|2011-07-01|
# |        015|          106|  Michael Lee| 37|  Male| 63000|2014-09-30|
# |        017|          105|  George Wang| 34|  Male| 57000|2016-03-15|
# |        019|          103|  Steven Chen| 36|  Male| 62000|2015-08-01|
# |        020|          102|    Grace Kim| 32|Female| 53000|2018-11-01|
# +-----------+-------------+-------------+---+------+------+----------+

# %%
# for schema 
emp.printSchema()
emp.schema
# Out:
# root
#  |-- employee_id: string (nullable = true)
#  |-- department_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- salary: string (nullable = true)
#  |-- hire_date: string (nullable = true)
# StructType([StructField('employee_id', StringType(), True), StructField('department_id', StringType(), True), StructField('name', StringType(), True), StructField('age', StringType(), True), StructField('gender', StringType(), True), StructField('salary', StringType(), True), StructField('hire_date', StringType(), True)])

# %%
from pyspark.sql.types import StructType,StructField,IntegerType,StringType
schema_string='name string, age int'

schema_park=StructType([
    StructField("name",StringType(),True),
    StructField("age",IntegerType(),True),
])

# %%
# Columns and expression
from pyspark.sql.functions import col, expr

emp["salary"]

# %%
# print the employee id ,name , age slary from emp df
from pyspark.sql.functions import col, expr
# emp.show()
emp_filter=emp.select(col('employee_id'),expr('name'), emp.salary,emp.age)
emp_filter.show()
# Out:
# +-----------+-------------+------+---+
# |employee_id|         name|salary|age|
# +-----------+-------------+------+---+
# |        001|     John Doe| 50000| 30|
# |        002|   Jane Smith| 45000| 25|
# |        003|    Bob Brown| 55000| 35|
# |        004|    Alice Lee| 48000| 28|
# |        005|    Jack Chan| 60000| 40|
# |        006|    Jill Wong| 52000| 32|
# |        007|James Johnson| 70000| 42|
# |        008|     Kate Kim| 51000| 29|
# |        009|      Tom Tan| 58000| 33|
# |        010|     Lisa Lee| 47000| 27|
# |        011|   David Park| 65000| 38|
# |        012|   Susan Chen| 54000| 31|
# |        013|    Brian Kim| 75000| 45|
# |        014|    Emily Lee| 46000| 26|
# |        015|  Michael Lee| 63000| 37|
# |        016|  Kelly Zhang| 49000| 30|
# |        017|  George Wang| 57000| 34|
# |        018|    Nancy Liu| 50000| 29|
# |        019|  Steven Chen| 62000| 36|
# |        020|    Grace Kim| 53000| 32|
# +-----------+-------------+------+---+

# %%
# emplyee_id as emp_id and cast(age as int ) 
emp_casted=emp.select(expr("employee_id as emp_id"),emp.name,expr("cast(age as int) as age"),emp.salary)
emp_casted.show()
#
# Out:
# +------+-------------+---+------+
# |emp_id|         name|age|salary|
# +------+-------------+---+------+
# |   001|     John Doe| 30| 50000|
# |   002|   Jane Smith| 25| 45000|
# |   003|    Bob Brown| 35| 55000|
# |   004|    Alice Lee| 28| 48000|
# |   005|    Jack Chan| 40| 60000|
# |   006|    Jill Wong| 32| 52000|
# |   007|James Johnson| 42| 70000|
# |   008|     Kate Kim| 29| 51000|
# |   009|      Tom Tan| 33| 58000|
# |   010|     Lisa Lee| 27| 47000|
# |   011|   David Park| 38| 65000|
# |   012|   Susan Chen| 31| 54000|
# |   013|    Brian Kim| 45| 75000|
# |   014|    Emily Lee| 26| 46000|
# |   015|  Michael Lee| 37| 63000|
# |   016|  Kelly Zhang| 30| 49000|
# |   017|  George Wang| 34| 57000|
# |   018|    Nancy Liu| 29| 50000|
# |   019|  Steven Chen| 36| 62000|
# |   020|    Grace Kim| 32| 53000|
# +------+-------------+---+------+

# %%
# filter age > 30
emp_final=emp_casted.select(emp.age,emp.emp_id,emp.name,emp.salary).where(emp.age>30)
emp_final.show()
# Out:
# +---+------+-------------+------+
# |age|emp_id|         name|salary|
# +---+------+-------------+------+
# | 35|   003|    Bob Brown| 55000|
# | 40|   005|    Jack Chan| 60000|
# | 32|   006|    Jill Wong| 52000|
# | 42|   007|James Johnson| 70000|
# | 33|   009|      Tom Tan| 58000|
# | 38|   011|   David Park| 65000|
# | 31|   012|   Susan Chen| 54000|
# | 45|   013|    Brian Kim| 75000|
# | 37|   015|  Michael Lee| 63000|
# | 34|   017|  George Wang| 57000|
# | 36|   019|  Steven Chen| 62000|
# | 32|   020|    Grace Kim| 53000|
# +---+------+-------------+------+
